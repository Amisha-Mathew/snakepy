# %% [markdown]
# # MI Assignment 1 [UE20CS060]

# %% [markdown]
# Before we start working with the notebook and xlsx files, we first understand what is present in the dataset.
#
# The dataset consists of the following columns:
# 1. InvoiceNo
# 2. StockCode
# 3. Description
# 4. Quantity
# 5. InvoiceDate
# 6. UnitPrice
# 7. CustomerID
# 8. Country

# %% [markdown]
# ### Procedure followed throughout the project

# %% [markdown]
# 1. Importing Packages
# 2. Data Inspection
#     - Dataset at a glance
#     - Columns at a glance
#     - To check whether data contains any null values
# 3. Data Cleaning
#     - Dropping data column
#     - Populating the missing ages
#     - Missing

# %% [markdown]
# ## 1. Importing Python Packages

# %%
import pandas as pd
import xlrd as xl
import numpy as np

# %% [markdown]
# ## 2. Data Inspection

# %%
df = pd.read_excel('1_Assignment_Online Retail.xlsx', engine='openpyxl', sheet_name='Online Retail')
# df = pd.read_excel('abc.xlsx', engine='openpyxl', sheet_name='Sheet1')

# This may take sometime to give an output
display(df)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
# Describing all the numerical columns and it important calculations
# Note how the UnitPrice and Quantity are negative values
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# Checking if null values are present
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Printing all the unique records of a column
# This concludes that the description is irrelevant to the prediction model

df['Description'].unique().tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda\envs\main\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Description'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# C:\Users\ANUSHK~1\AppData\Local\Temp/ipykernel_4388/2677097315.py in <module>
#       1 # Printing all the unique records of a column
#       2 # This concludes that the description is irrelevant to the prediction model
# ----> 3 df['Description'].unique().tolist()
#
# C:\ProgramData\Anaconda\envs\main\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# C:\ProgramData\Anaconda\envs\main\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Description'

# %%
# Printing all the unique records of a column
# This concludes that the InvoiceNo is irrelevant to the prediction model

df['InvoiceNo'].unique().tolist()

# %%
# Description and InvoiceNo play no significant role in the prediction model
# Hence Dropping  Description and InvoiceNo

df.drop('Description', axis=1, inplace=True)
df.drop('InvoiceNo', axis=1, inplace=True)

# %%
# To ensure secured dropping of columns
# printing all the column names
list(df.columns.values)
# Out:
# ['StockCode', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country']

# %%
# checking if null values are present
df.isnull().sum()
# Out:
# StockCode           0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Dropping tuples where the customerID is null
# Becomes irrelevant to the Prediction Model

df.dropna(subset=['CustomerID'], inplace = True)
df.isnull().sum()
# Out:
# StockCode      0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
# Checking the datatypes of columns
print(df.dtypes)
# Out:
# StockCode              object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
# Inserting a column to determine the total purchase 

df['Total'] = df['Quantity'] + df['UnitPrice']
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID          Total
# count  406829.000000  406829.000000  406829.000000  406829.000000
# mean       12.061303       3.460471   15287.690570      15.521774
# std       248.693370      69.315162    1713.600303     258.089736
# min    -80995.000000       0.000000   12346.000000  -80992.920000
# 25%         2.000000       1.250000   13953.000000       4.950000
# 50%         5.000000       1.950000   15152.000000       8.950000
# 75%        12.000000       3.750000   16791.000000      13.490000
# max     80995.000000   38970.000000   18287.000000   80997.080000

# %%
# Printing all the unique records of a column
# This concludes that the Country is irrelevant to the prediction model
countrylist = df['Country'].unique()

countrydf = pd.DataFrame(countrylist, columns =['countryName'])
countrydf
# Out:
#              countryName
# 0         United Kingdom
# 1                 France
# 2              Australia
# 3            Netherlands
# 4                Germany
# 5                 Norway
# 6                   EIRE
# 7            Switzerland
# 8                  Spain
# 9                 Poland
# 10              Portugal
# 11                 Italy
# 12               Belgium
# 13             Lithuania
# 14                 Japan
# 15               Iceland
# 16       Channel Islands
# 17               Denmark
# 18                Cyprus
# 19                Sweden
# 20               Austria
# 21                Israel
# 22               Finland
# 23                Greece
# 24             Singapore
# 25               Lebanon
# 26  United Arab Emirates
# 27          Saudi Arabia
# 28        Czech Republic
# 29                Canada
# 30           Unspecified
# 31                Brazil
# 32                   USA
# 33    European Community
# 34               Bahrain
# 35                 Malta
# 36                   RSA

# %%
# Generating CodeNumber for Countries
# This makes country-based predictions a lot easier

# converting type of columns to 'category'
df['Country'] = df['Country'].astype('category')

# Assigning numerical values and storing in another column
df['codeNo'] = df['Country'].cat.codes

df.head(30)
# Out:
#    StockCode  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 0     85123A         6 2010-12-01 08:26:00       2.55     17850.0
# 1      71053         6 2010-12-01 08:26:00       3.39     17850.0
# 2     84406B         8 2010-12-01 08:26:00       2.75     17850.0
# 3     84029G         6 2010-12-01 08:26:00       3.39     17850.0
# 4     84029E         6 2010-12-01 08:26:00       3.39     17850.0
# 5      22752         2 2010-12-01 08:26:00       7.65     17850.0
# 6      21730         6 2010-12-01 08:26:00       4.25     17850.0
# 7      22633         6 2010-12-01 08:28:00       1.85     17850.0
# 8      22632         6 2010-12-01 08:28:00       1.85     17850.0
# 9      84879        32 2010-12-01 08:34:00       1.69     13047.0
# 10     22745         6 2010-12-01 08:34:00       2.10     13047.0
# 11     22748         6 2010-12-01 08:34:00       2.10     13047.0
# 12     22749         8 2010-12-01 08:34:00       3.75     13047.0
# 13     22310         6 2010-12-01 08:34:00       1.65     13047.0
# 14     84969         6 2010-12-01 08:34:00       4.25     13047.0
# 15     22623         3 2010-12-01 08:34:00       4.95     13047.0
# 16     22622         2 2010-12-01 08:34:00       9.95     13047.0
# 17     21754         3 2010-12-01 08:34:00       5.95     13047.0
# 18     21755         3 2010-12-01 08:34:00       5.95     13047.0
# 19     21777         4 2010-12-01 08:34:00       7.95     13047.0
# 20     48187         4 2010-12-01 08:34:00       7.95     13047.0
# 21     22960         6 2010-12-01 08:34:00       4.25     13047.0
# 22     22913         3 2010-12-01 08:34:00       4.95     13047.0
# 23     22912         3 2010-12-01 08:34:00       4.95     13047.0
# 24     22914         3 2010-12-01 08:34:00       4.95     13047.0
# 25     21756         3 2010-12-01 08:35:00       5.95     13047.0
# 26     22728        24 2010-12-01 08:45:00       3.75     12583.0
# 27     22727        24 2010-12-01 08:45:00       3.75     12583.0
# 28     22726        12 2010-12-01 08:45:00       3.75     12583.0
# 29     21724        12 2010-12-01 08:45:00       0.85     12583.0
#
#            Country  Total  codeNo
# 0   United Kingdom   8.55      35
# 1   United Kingdom   9.39      35
# 2   United Kingdom  10.75      35
# 3   United Kingdom   9.39      35
# 4   United Kingdom   9.39      35
# 5   United Kingdom   9.65      35
# 6   United Kingdom  10.25      35
# 7   United Kingdom   7.85      35
# 8   United Kingdom   7.85      35
# 9   United Kingdom  33.69      35
# 10  United Kingdom   8.10      35
# 11  United Kingdom   8.10      35
# 12  United Kingdom  11.75      35
# 13  United Kingdom   7.65      35
# 14  United Kingdom  10.25      35
# 15  United Kingdom   7.95      35
# 16  United Kingdom  11.95      35
# 17  United Kingdom   8.95      35
# 18  United Kingdom   8.95      35
# 19  United Kingdom  11.95      35
# 20  United Kingdom  11.95      35
# 21  United Kingdom  10.25      35
# 22  United Kingdom   7.95      35
# 23  United Kingdom   7.95      35
# 24  United Kingdom   7.95      35
# 25  United Kingdom   8.95      35
# 26          France  27.75      13
# 27          France  27.75      13
# 28          France  15.75      13
# 29          France  12.85      13

# %%
# Checking if null values are present
# More focussed towards ensuring codeNo is filled in properly
df.isnull().sum()
# Out:
# StockCode      0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# Total          0
# codeNo         0
# dtype: int64

# %%
# Checking for one parameter 
# whether the codeNo has been correctly mapped or not
count = 0

if ((df['Country']=='United Kingdom') & (df['codeNo'] != 35)).any():
    count += 1
    
print(count)
# Out:
# 0

# %%
# TODO
# checking for all 'country' parameter rightly mapped
checker_df = df.loc[(df['Country']=='France') & (df['codeNo'] != 13)]
checker_df.head(10)
# Out:
# Empty DataFrame
# Columns: [StockCode, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, Total, codeNo]
# Index: []
